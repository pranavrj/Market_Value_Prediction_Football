# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df1=pd.read_excel("midfielders_dataset1.xlsx")
df2=pd.read_excel("forwards_dataset1.xlsx")
df3=pd.read_excel("defenders_dataset1.xlsx")

# %%
df1.head()
# Out:
#    age  Market_Value  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  dribbling  long_passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  stamina  strength  long_shots  aggression  interceptions  positioning  vision  composure  marking  Tackling
# 0   27          69.5                 4        88         81                52             91         84            89            91            76            73       80         88       81       92        58          89          46             56           84      91         88       59      39.5
# 1   25          73.0                 5        80         75                75             86         87            90            90            71            79       76         82       66       88        87          82          78             64           82      88         87       63      67.0
# ...

# %%
df2.head()
# Out:
#          name  age  overall_rating  potential  Market_Value  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  volleys  dribbling  long_passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  shot_power  jumping  stamina  strength  long_shots  aggression  positioning  vision  composure
# 0    L. Messi   31              94         94         110.5                 4        86         95                70             92       86         97            89            96            91            86       93         95       95          85       68       72        66          94          48           94      94         96
# ...

# %%
df3.head()
# Out:
#             name  age  overall_rating  potential  Market_Value  heading_accuracy  Passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  jumping  stamina  strength  aggression  interceptions  positioning  composure  marking  Tackling
# 0   K. Koulibaly   27              88         91          60.0                83     64.0            63            70            75       50         82       40       81       75        94          87             88           24         80       91      87.5
# 1    V. van Dijk   27              88         90          59.5                83     80.0            76            74            77       61         87       49       88       75        92          82             88           41         87       90      86.5
# ...

# %%
df1.describe()
# Out:
#                age  overall_rating    potential  Market_Value  skill_moves(1-5)     crossing    finishing  heading_accuracy  short_passing    dribbling  long_passing  ball_control  acceleration  sprint_speed      agility    reactions      balance      stamina     strength   long_shots   aggression  interceptions  positioning       vision    composure      marking     Tackling
# count  5746.000000     5746.000000  5746.000000   5746.000000       5746.000000  5746.000000  5746.000000       5746.000000     5746.00000  5746.000000   5746.000000   5746.000000   5746.000000   5746.000000  5746.000000  5746.000000  5746.000000  5746.000000  5746.000000  5746.000000  5746.000000    5746.000000  5746.000000  5746.000000  5746.000000  5746.000000  5746.000000
# ...

# %%
df2.describe()
# Out:
#                age  overall_rating    potential  Market_Value  skill_moves(1-5)     crossing    finishing  heading_accuracy  short_passing      volleys    dribbling  long_passing  ball_control  acceleration  sprint_speed      agility    reactions      balance   shot_power      jumping      stamina     strength   long_shots   aggression  positioning       vision    composure
# count  4016.000000     4016.000000  4016.000000   4016.000000       4016.000000  4016.000000  4016.000000       4016.000000    4016.000000  4016.000000  4016.000000   4016.000000   4016.000000   4016.000000   4016.000000  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000
# ...

# %%
df3.describe()
# Out:
#                age  overall_rating   potential  Market_Value  heading_accuracy      Passing  ball_control  acceleration  sprint_speed      agility    reactions      balance      jumping      stamina     strength   aggression  interceptions  positioning    composure      marking     Tackling
# count  5913.000000     5913.000000  5913.00000   5913.000000       5913.000000  5913.000000   5913.000000   5913.000000   5913.000000  5913.000000  5913.000000  5913.000000  5913.000000  5913.000000  5913.000000  5913.000000    5913.000000  5913.000000  5913.000000  5913.000000  5913.000000
# mean     25.840859       66.324539    71.13631      2.026063         60.792660    56.479537     57.922713     64.829528     65.784035    60.593607    61.590225    61.772028    68.874852    68.029596    70.188737    65.189244      63.515474    44.374429    58.552681    63.501268    65.560629
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5746 entries, 0 to 5745
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              5746 non-null   object
#  1   age               5746 non-null   int64
#  2   overall_rating    5746 non-null   int64
#  3   potential         5746 non-null   int64
#  4   Market_Value      5746 non-null   float64
#  5   skill_moves(1-5)  5746 non-null   int64
#  6   crossing          5746 non-null   int64
#  7   finishing         5746 non-null   int64
#  8   heading_accuracy  5746 non-null   int64
#  9   short_passing     5746 non-null   int64
#  10  dribbling         5746 non-null   int64
#  11  long_passing      5746 non-null   int64
#  12  ball_control      5746 non-null   int64
#  13  acceleration      5746 non-null   int64
#  14  sprint_speed      5746 non-null   int64
#  15  agility           5746 non-null   int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4016 entries, 0 to 4015
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              4016 non-null   object
#  1   age               4016 non-null   int64
#  2   overall_rating    4016 non-null   int64
#  3   potential         4016 non-null   int64
#  4   Market_Value      4016 non-null   float64
#  5   skill_moves(1-5)  4016 non-null   int64
#  6   crossing          4016 non-null   int64
#  7   finishing         4016 non-null   int64
#  8   heading_accuracy  4016 non-null   int64
#  9   short_passing     4016 non-null   int64
#  10  volleys           4016 non-null   int64
#  11  dribbling         4016 non-null   int64
#  12  long_passing      4016 non-null   int64
#  13  ball_control      4016 non-null   int64
#  14  acceleration      4016 non-null   int64
#  15  sprint_speed      4016 non-null   int64
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5913 entries, 0 to 5912
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              5913 non-null   object
#  1   age               5913 non-null   int64
#  2   overall_rating    5913 non-null   int64
#  3   potential         5913 non-null   int64
#  4   Market_Value      5913 non-null   float64
#  5   heading_accuracy  5913 non-null   int64
#  6   Passing           5913 non-null   float64
#  7   ball_control      5913 non-null   int64
#  8   acceleration      5913 non-null   int64
#  9   sprint_speed      5913 non-null   int64
#  10  agility           5913 non-null   int64
#  11  reactions         5913 non-null   int64
#  12  balance           5913 non-null   int64
#  13  jumping           5913 non-null   int64
#  14  stamina           5913 non-null   int64
#  15  strength          5913 non-null   int64
# ...

# %%
df1.drop(["overall_rating","potential"],axis=1, inplace=True)

# %%
d1 = df1.hist(bins=50, figsize=(16,12))

# %%
df2.drop(["overall_rating","potential"],axis=1,inplace=True)

# %%
df3.drop(["overall_rating","potential"],axis=1,inplace=True)

# %%
d2 = df2.hist(bins=50, figsize=(16,12))

# %%
d3 = df3.hist(bins=50, figsize=(16,12))

# %%
df1.drop(columns=["name"], inplace=True)
df2.drop(columns=["name"], inplace=True)
df3.drop(columns=["name"], inplace=True)

# %%
df1.corr()
# Out:
#                        age  Market_Value  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  dribbling  long_passing  ball_control  acceleration  sprint_speed   agility  reactions   balance   stamina  strength  long_shots  aggression  interceptions  positioning    vision  composure   marking  Tackling
# age               1.000000      0.092017          0.170448  0.399037   0.295018          0.322793       0.365842   0.214239      0.372323      0.347149     -0.194644     -0.213419  0.037723   0.475078 -0.053492  0.298170  0.382946    0.447347    0.365998       0.349239     0.357982  0.385225   0.468529  0.279546  0.234441
# Market_Value      0.092017      1.000000          0.416054  0.423022   0.397917          0.225663       0.580386   0.539269      0.506664      0.602718      0.153874      0.120360  0.212919   0.559002  0.115979  0.302616  0.158877    0.432758    0.219132       0.260666     0.464788  0.536806   0.518821  0.250876  0.215503
# ...

# %%
df2.corr()
# Out:
#                        age  Market_Value  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing   volleys  dribbling  long_passing  ball_control  acceleration  sprint_speed   agility  reactions   balance  shot_power   jumping   stamina  strength  long_shots  aggression  positioning    vision  composure
# age               1.000000      0.123632          0.194631  0.322529   0.416165          0.397118       0.397316  0.527511   0.251079      0.325627      0.368634     -0.151740     -0.135070  0.021827   0.510931 -0.066306    0.465573  0.218878  0.281454  0.365038    0.459984    0.445196     0.533163  0.385769   0.521235
# Market_Value      0.123632      1.000000          0.445087  0.384368   0.535223          0.215659       0.519075  0.473038   0.534717      0.393100      0.582050      0.232636      0.230220  0.267520   0.573781  0.173434    0.468313  0.118674  0.318812  0.107782    0.497372    0.216551     0.549996  0.504819   0.533159
# ...

# %%
df3.corr()
# Out:
#                        age  Market_Value  heading_accuracy   Passing  ball_control  acceleration  sprint_speed   agility  reactions   balance   jumping   stamina  strength  aggression  interceptions  positioning  composure   marking  Tackling
# age               1.000000      0.069695          0.365407  0.383496      0.287959     -0.222865     -0.209531  0.001725   0.441317 -0.085232  0.121562  0.138210  0.346993    0.452221       0.430515     0.152014   0.502388  0.412315  0.369473
# Market_Value      0.069695      1.000000          0.421466  0.437035      0.413762      0.111479      0.168516  0.099715   0.579634  0.002213  0.190113  0.235354  0.213720    0.389107       0.565992     0.176784   0.507599  0.547360  0.605317
# heading_accuracy  0.365407      0.421466          1.000000  0.366246      0.183312     -0.395721     -0.302284 -0.322379   0.491465 -0.437696  0.217468  0.011753  0.643697    0.542099       0.635061    -0.183199   0.525464  0.634483  0.648765
# ...

# %%
from sklearn.model_selection import train_test_split

trainset1, testset1 = train_test_split(df1, test_size=0.2,
                                      random_state=7)
trainset2, testset2 = train_test_split(df2, test_size=0.2,
                                      random_state=7)
trainset3, testset3 = train_test_split(df3, test_size=0.2,
                                      random_state=7)

# %%
trainset1.head()
# Out:
#       age  Market_Value  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  dribbling  long_passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  stamina  strength  long_shots  aggression  interceptions  positioning  vision  composure  marking  Tackling
# 24     21         31.00                 4        75         52                64             87         86            82            88            80            78       84         83       78       74        69          57          64             78           66      85         86       69      71.5
# 4578   23          2.50                 3        72         62                51             70         77            62            75            78            79       76         59       76       56        46          55          33             28           60      57         62       30      30.0
# ...

# %%
trainset2.head()
# Out:
#       age  Market_Value  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  volleys  dribbling  long_passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  shot_power  jumping  stamina  strength  long_shots  aggression  positioning  vision  composure
# 3291   25          3.20                 3        66         76                66             66       55         65            59            66            76            77       72         63       64          73       63       84        76          62          54           71      59         68
# 2716   24          1.20                 3        64         70                53             69       57         70            60            70            73            70       83         64       68          67       70       68        56          61          54           64      62         58
# ...

# %%
trainset3.head()
# Out:
#       age  Market_Value  heading_accuracy  Passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  jumping  stamina  strength  aggression  interceptions  positioning  composure  marking  Tackling
# 3326   30         0.400                59     57.0            55            54            54       48         55       60       73       60        69          52             67           34         50       67      67.5
# 171    36         1.300                78     45.0            49            32            46       32         60       32       68       33        91          73             78           20         72       76      75.0
# 2651   27         0.290                42     56.0            64            76            72       75         58       77       72       73        69          59             51           58         50       52      61.0
# ...

# %%
testset1.head()
# Out:
#       age  Market_Value  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  dribbling  long_passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  stamina  strength  long_shots  aggression  interceptions  positioning  vision  composure  marking  Tackling
# 4458   36          0.75                 3        68         51                50             69         71            65            70            80            77       81         72       81       76        71          65          72             72           66      76         74       56      63.0
# 5491   26         11.00                 4        68         70                56             81         77            79            79            69            67       76         78       77       74        60          66          65             74           69      80         75       61      72.5
# ...

# %%
testset2.head()
# Out:
#       age  Market_Value  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  volleys  dribbling  long_passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  shot_power  jumping  stamina  strength  long_shots  aggression  positioning  vision  composure
# 3839   35           5.5                 4        74         79                74             76       84         80            72            86            59            50       73         79       57          80       50       52        67          77          41           85      80         85
# 3031   19           3.7                 3        65         66                53             69       45         73            63            72            74            76       77         62       74          64       62       67        55          63          40           73      65         50
# ...

# %%
testset3.head()
# Out:
#       age  Market_Value  heading_accuracy  Passing  ball_control  acceleration  sprint_speed  agility  reactions  balance  jumping  stamina  strength  aggression  interceptions  positioning  composure  marking  Tackling
# 876    26         0.525                56     57.5            61            75            81       74         66       72       75       71        61          71             61           41         60       63      63.0
# 5685   28         7.500                80     73.5            74            69            76       66         67       57       80       85        79          69             75           67         71       75      77.5
# 4144   25         0.975                70     50.0            51            60            59       46         55       54       78       75        80          70             63           29         59       67      67.0
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# take the target variable out before scaling
trainset_target = trainset1["Market_Value"].values
trainset_predictors = trainset1.drop("Market_Value", axis=1)

# fit_transform returns a NumPy array, so we need to put it back 
# into a Pandas dataframe
scaled_vals = scaler.fit_transform(trainset_predictors)
trainset1 = pd.DataFrame(scaled_vals, columns=trainset_predictors.columns)

# put the non-scaled target back in
trainset1['Market_Value'] = trainset_target

# inspect the data
trainset1.head()
# Out:
#         age  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  dribbling  long_passing  ball_control  acceleration  sprint_speed   agility  reactions   balance   stamina  strength  long_shots  aggression  interceptions  positioning    vision  composure   marking  Tackling  Market_Value
# 0 -0.901251          2.129646  1.565922  -0.101389          1.114730       2.595368   2.464481      2.123665      2.716291      1.160855      1.051366  1.421747   2.320317  0.725776  0.471763  0.594657   -0.000429    0.306513       1.540371     0.736484  2.366352   2.406780  1.130040  1.269341         31.00
# 1 -0.462603          0.506722  1.291605   0.759475         -0.099455       0.364256   1.418709     -0.119349      1.072552      0.958343      1.153226  0.625603  -0.403814  0.526762 -1.050272 -1.285295   -0.158127   -1.844753      -1.449353     0.153571 -0.606848   0.019886 -1.521315 -1.466171          2.50
# ...

# %%
testset_target = testset1["Market_Value"].values
testset_predictors = testset1.drop("Market_Value", axis=1)

scaled_vals = scaler.transform(testset_predictors)
testset1 = pd.DataFrame(scaled_vals, columns=testset_predictors.columns)

# put the non-scaled target back in
testset1['Market_Value'] = testset_target

testset1.head()
# Out:
#         age  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing  dribbling  long_passing  ball_control  acceleration  sprint_speed   agility  reactions   balance   stamina  strength  long_shots  aggression  interceptions  positioning    vision  composure   marking  Tackling  Market_Value
# 0  2.388605          0.506722  0.925849  -0.187476         -0.192853       0.233014   0.721528      0.217103      0.440344      1.160855      0.949505  1.123193   1.071757  1.024296  0.640878  0.758131    0.630363    0.861678       1.181605     0.736484  1.410681   1.213333  0.246255  0.709056          0.75
# 1  0.195368          2.129646  0.925849   1.448166          0.367539       1.807917   1.418709      1.787213      1.578317      0.047037     -0.069104  0.625603   1.752790  0.626269  0.471763 -0.140977    0.709213    0.375908       1.301194     1.027941  1.835424   1.312787  0.586172  1.335257         11.00
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# take the target variable out before scaling
trainset_target = trainset2["Market_Value"].values
trainset_predictors = trainset2.drop("Market_Value", axis=1)

# fit_transform returns a NumPy array, so we need to put it back 
# into a Pandas dataframe
scaled_vals = scaler.fit_transform(trainset_predictors)
trainset2 = pd.DataFrame(scaled_vals, columns=trainset_predictors.columns)

# put the non-scaled target back in
trainset2['Market_Value'] = trainset_target

# inspect the data
trainset2.head()
# Out:
#         age  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing   volleys  dribbling  long_passing  ball_control  acceleration  sprint_speed   agility  reactions   balance  shot_power   jumping   stamina  strength  long_shots  aggression  positioning    vision  composure  Market_Value
# 0 -0.037948          0.330591  0.923284   1.292107          0.600298       0.537085 -0.263815  -0.142494      0.747624     -0.029195      0.300024      0.403124  0.147101   0.051729 -0.308901    0.713602 -0.235648  1.848805  0.818810    0.201113    0.157514     0.625676  0.068486   0.646705          3.20
# 1 -0.258758          0.330591  0.779641   0.546777         -0.479251       0.855902 -0.085383   0.410539      0.829817      0.442629      0.029303     -0.269567  1.121301   0.157896  0.022630    0.059405  0.357402  0.294133 -0.683456    0.098821    0.157514    -0.142799  0.366425  -0.342398          1.20
# ...

# %%
testset_target = testset2["Market_Value"].values
testset_predictors = testset2.drop("Market_Value", axis=1)

scaled_vals = scaler.transform(testset_predictors)
testset2 = pd.DataFrame(scaled_vals, columns=testset_predictors.columns)

# put the non-scaled target back in
testset2['Market_Value'] = testset_target

testset2.head()
# Out:
#         age  skill_moves(1-5)  crossing  finishing  heading_accuracy  short_passing   volleys  dribbling  long_passing  ball_control  acceleration  sprint_speed   agility  reactions   balance  shot_power   jumping   stamina  strength  long_shots  aggression  positioning    vision  composure  Market_Value
# 0  2.170161          1.830389  1.497857   1.664772          1.264635       1.599809  2.323452   1.516605      1.816140      2.329929     -1.234064     -2.191543  0.235664   1.750412 -0.889081    1.476832 -1.337025 -1.260540  0.142790    1.735493   -0.700226     2.162625  2.154058   2.328180           5.5
# 1 -1.362813          0.330591  0.851462   0.049890         -0.479251       0.855902 -1.155977   0.742359      1.076398      0.678542      0.119543      0.307026  0.589919  -0.054439  0.519927   -0.267694 -0.320369  0.196966 -0.758570    0.303405   -0.766206     0.845240  0.664364  -1.133681           3.7
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# take the target variable out before scaling
trainset_target = trainset3["Market_Value"].values
trainset_predictors = trainset3.drop("Market_Value", axis=1)

# fit_transform returns a NumPy array, so we need to put it back 
# into a Pandas dataframe
scaled_vals = scaler.fit_transform(trainset_predictors)
trainset3 = pd.DataFrame(scaled_vals, columns=trainset_predictors.columns)

# put the non-scaled target back in
trainset3['Market_Value'] = trainset_target

# inspect the data
trainset3.head()
# Out:
#         age  heading_accuracy   Passing  ball_control  acceleration  sprint_speed   agility  reactions   balance   jumping   stamina  strength  aggression  interceptions  positioning  composure   marking  Tackling  Market_Value
# 0  0.914108         -0.176592  0.041097     -0.283500     -0.881480     -0.979436 -0.995415  -0.793394 -0.145614  0.385305 -0.792452 -0.109116   -1.254099       0.397168    -0.707976  -0.864124  0.407077  0.255863         0.400
# 1  2.231115          1.672450 -1.076612     -0.846413     -2.669736     -1.641610 -2.258777  -0.198437 -2.417384 -0.090566 -3.435821  1.910926    0.729178       1.682843    -1.663898   1.330082  1.474809  1.273148         1.300
# 2  0.255605         -1.830998 -0.052046      0.560870      0.906776      0.510455  1.136508  -0.436420  1.233676  0.290131  0.480281 -0.109116   -0.593007      -1.472905     0.930746  -0.864124 -1.372475 -0.625785         0.290
# ...

# %%
testset_target = testset3["Market_Value"].values
testset_predictors = testset3.drop("Market_Value", axis=1)

scaled_vals = scaler.transform(testset_predictors)
testset3 = pd.DataFrame(scaled_vals, columns=testset_predictors.columns)

# put the non-scaled target back in
testset3['Market_Value'] = testset_target

testset3.head()
# Out:
#         age  heading_accuracy   Passing  ball_control  acceleration  sprint_speed   agility  reactions   balance   jumping   stamina  strength  aggression  interceptions  positioning  composure   marking  Tackling  Market_Value
# 0  0.036104         -0.468546  0.087668      0.279414      0.825492      1.255400  1.057548   0.515513  0.828002  0.575654  0.284476 -0.843677    0.540295      -0.304109    -0.230016   0.133242 -0.067470 -0.354509         0.525
# 1  0.475106          1.867086  1.577946      1.499059      0.337785      0.841542  0.425867   0.634504 -0.389018  1.051525  1.655112  0.809085    0.351411       1.332205     1.545266   1.230345  1.356172  1.612243         7.500
# 2 -0.183397          0.893906 -0.610900     -0.658775     -0.393774     -0.565578 -1.153335  -0.793394 -0.632421  0.861176  0.676087  0.900905    0.445853      -0.070350    -1.049377   0.033506  0.407077  0.188044         0.975
# ...

# %%
from sklearn.model_selection import GridSearchCV

# drop labels for training set, but keep all others
Xtrain1 = trainset1.drop("Market_Value", axis=1)

ytrain1 = trainset1["Market_Value"].copy()

Xtrain2 = trainset2.drop("Market_Value", axis=1)

ytrain2 = trainset2["Market_Value"].copy()

Xtrain3 = trainset3.drop("Market_Value", axis=1)

ytrain3 = trainset3["Market_Value"].copy()

# %%
Xtest1 = testset1.drop("Market_Value", axis=1)
ytest1 = testset1["Market_Value"].copy()

Xtest2 = testset2.drop("Market_Value", axis=1)
ytest2 = testset2["Market_Value"].copy()

Xtest3 = testset3.drop("Market_Value", axis=1)
ytest3 = testset3["Market_Value"].copy()

# %%
# Baseline model
from sklearn.dummy import DummyRegressor
import numpy as np

# %%
#dataset 1
dummy_reg = DummyRegressor(strategy='mean')
# fit it on the training set
dummy_reg.fit(Xtrain1, ytrain1)
# make predictions on the test set
ypred1 = dummy_reg.predict(Xtest1)

mse = mean_squared_error(ytest1, ypred1)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('MAE:', metrics.mean_absolute_error(ytest1, ypred1))
# Out:
# MSE:  31.008503893385033
# RMSE:  5.568527982634642
# MAE: 2.9535922219699553

# %%
#dataset 2
dummy_reg = DummyRegressor(strategy='mean')
# fit it on the training set
dummy_reg.fit(Xtrain2, ytrain2)
# make predictions on the test set
ypred2 = dummy_reg.predict(Xtest2)

mse = mean_squared_error(ytest2, ypred2)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('MAE:', metrics.mean_absolute_error(ytest2, ypred2))
# Out:
# MSE:  41.99098200681713
# RMSE:  6.48004490777781
# MAE: 3.6002407560578176

# %%
#dataset 3
dummy_reg = DummyRegressor(strategy='mean')
# fit it on the training set
dummy_reg.fit(Xtrain3, ytrain3)
# make predictions on the test set
ypred3 = dummy_reg.predict(Xtest3)

mse = mean_squared_error(ytest3, ypred3)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('MAE:', metrics.mean_absolute_error(ytest3, ypred3))
# Out:
# MSE:  16.239460334832902
# RMSE:  4.029821377534357
# MAE: 2.1218004401680606

# %%
from sklearn.ensemble import RandomForestRegressor
import time

# %%
rf1 = RandomForestRegressor(random_state=7)

# specify the hyperparameters and their values
# 4 x 2 x 2 = 16 combinations in the grid
param_grid = {
    'n_estimators': [10, 100, 200, 500],
    'max_depth': [5, 15],
    'min_samples_split': [5, 10]
}

# we'll use 5-fold cross-validation
grid_search = GridSearchCV(rf1, param_grid, cv=5, 
                           return_train_score=True) 

start = time.time()
grid_search.fit(Xtrain1, ytrain1)
end = time.time() - start
print(f"Took {end} seconds")
# Out:
# Took 270.38119888305664 seconds

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=15, min_samples_split=5, n_estimators=200,
#                       random_state=7)

# %%
grid_search.best_score_
# Out:
# 0.9126302749357602

# %%
# put them into a separate variable for convenience
feature_importances = grid_search.best_estimator_.feature_importances_

# the order of the features in `feature_importances` is the same as in the Xtrain dataframe,
# so we can "zip" the two and print in the descending order:

for k, v in sorted(zip(feature_importances, Xtrain1.columns), reverse=True):
    print(f"{v}: {k}")
# Out:
# ball_control: 0.703397756998624
# reactions: 0.07689924069110614
# short_passing: 0.03390887101435953
# age: 0.018548418588958983
# interceptions: 0.017343592491230946
# positioning: 0.016703997916644744
# vision: 0.015726157460797988
# stamina: 0.013953292884692544
# Tackling: 0.011958602521095348
# long_passing: 0.011629663130874494
# composure: 0.01151878506689228
# finishing: 0.01089468360757356
# long_shots: 0.00906127175480241
# dribbling: 0.008544835889680845
# marking: 0.0077557018719764895
# sprint_speed: 0.006258608671426837
# heading_accuracy: 0.0054013392411082104
# acceleration: 0.0040024372905835374
# aggression: 0.0038742158027068787
# crossing: 0.0037788799891904324
# balance: 0.003206903398255454
# strength: 0.00295223945111217
# agility: 0.002107221906703187
# skill_moves(1-5): 0.0005732823596030131

# %%
rf1 = RandomForestRegressor(n_estimators = 500, max_features = 'sqrt', max_depth = 15,
                           random_state = 18)
rf1.fit(Xtrain1, ytrain1)
# Out:
# RandomForestRegressor(max_depth=15, max_features='sqrt', n_estimators=500,
#                       random_state=18)

# %%
score = rf1.score(Xtrain1, ytrain1)
print("R-squared:", score)
# Out:
# R-squared: 0.9864772638924525

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error

# %%
ypred = rf1.predict(Xtest1)

mse = mean_squared_error(ytest1, ypred)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse)) 
print('MAE:', metrics.mean_absolute_error(ytest1, ypred))
# Out:
# MSE:  2.905213890398559
# RMSE:  1.704468800066038
# MAE: 0.6153978088557756

# %%
from sklearn.tree import plot_tree

# %%
fig = plt.figure(figsize=(15, 10))
plot_tree(rf1.estimators_[0], 
          feature_names=Xtrain1.columns,
          #class_names=ytrain1.columns, 
          filled=True, impurity=True, 
          rounded=True)
# Out:
# [Text(0.8312828690020863, 0.96875, 'composure <= 1.76\nsquared_error = 32.273\nsamples = 2893\nvalue = 2.609'),
#  Text(0.6919859396731571, 0.90625, 'crossing <= 0.88\nsquared_error = 10.632\nsamples = 2774\nvalue = 1.981'),
#  Text(0.5166347031467315, 0.84375, 'short_passing <= 0.824\nsquared_error = 4.632\nsamples = 2300\nvalue = 1.305'),
#  Text(0.3775165159944367, 0.78125, 'reactions <= 0.447\nsquared_error = 0.909\nsamples = 2043\nvalue = 0.798'),
#  Text(0.254504954798331, 0.71875, 'short_passing <= -0.226\nsquared_error = 0.289\nsamples = 1690\nvalue = 0.584'),
#  Text(0.15178633518776077, 0.65625, 'skill_moves(1-5) <= -0.305\nsquared_error = 0.126\nsamples = 1089\nvalue = 0.412'),
#  Text(0.07748609179415855, 0.59375, 'short_passing <= -0.62\nsquared_error = 0.039\nsamples = 694\nvalue = 0.28'),
#  Text(0.039933936022253126, 0.53125, 'long_shots <= -1.144\nsquared_error = 0.024\nsamples = 469\nvalue = 0.219'),
# ...

# %%
fig.savefig('figure_name.png')

# %%
rf2 = RandomForestRegressor(random_state=7)

# specify the hyperparameters and their values
# 4 x 2 x 2 = 16 combinations in the grid
param_grid = {
    'n_estimators': [10, 100, 200, 500],
    'max_depth': [5, 15],
    'min_samples_split': [5, 10]
}

# we'll use 5-fold cross-validation
grid_search = GridSearchCV(rf2, param_grid, cv=5, 
                           return_train_score=True) 

start = time.time()
grid_search.fit(Xtrain2, ytrain2)
end = time.time() - start
print(f"Took {end} seconds")
# Out:
# Took 182.76959824562073 seconds

# %%
grid_search.best_score_
# Out:
# 0.9122080318408597

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=15, min_samples_split=5, random_state=7)

# %%
# put them into a separate variable for convenience
feature_importances = grid_search.best_estimator_.feature_importances_

# the order of the features in `feature_importances` is the same as in the Xtrain dataframe,
# so we can "zip" the two and print in the descending order:

for k, v in sorted(zip(feature_importances, Xtrain2.columns), reverse=True):
    print(f"{v}: {k}")
# Out:
# reactions: 0.48844408907391623
# ball_control: 0.3332474298844713
# finishing: 0.029135638950820664
# dribbling: 0.016951023470811368
# stamina: 0.015527978911964928
# age: 0.014880585485581008
# composure: 0.012900591303562824
# positioning: 0.011366119836565212
# long_passing: 0.010233620582805204
# crossing: 0.009710624608720428
# sprint_speed: 0.008447958784722051
# long_shots: 0.008290895047199397
# shot_power: 0.006858081795964765
# acceleration: 0.00569436366509641
# aggression: 0.004450437119641912
# short_passing: 0.004327266945644486
# vision: 0.0036718266644448026
# agility: 0.003471121159243776
# volleys: 0.003246294115478218
# balance: 0.0026584678452001706
# jumping: 0.0021428739707439154
# strength: 0.002078343012468521
# heading_accuracy: 0.0018851049406878862
# skill_moves(1-5): 0.0003792628242444174

# %%
rf2 = RandomForestRegressor(n_estimators = 500, max_features = 'sqrt', max_depth = 15,
                           random_state = 18)
rf2.fit(Xtrain2, ytrain2)
# Out:
# RandomForestRegressor(max_depth=15, max_features='sqrt', n_estimators=500,
#                       random_state=18)

# %%
score = rf2.score(Xtrain2, ytrain2)
print("R-squared:", score)
# Out:
# R-squared: 0.9882322344744944

# %%
ypred = rf2.predict(Xtest2)

mse = mean_squared_error(ytest2, ypred)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('MAE:', metrics.mean_absolute_error(ytest2, ypred))
# Out:
# MSE:  5.282333097244824
# RMSE:  2.2983326776697983
# MAE: 0.8174798415934393

# %%
rf3 = RandomForestRegressor(random_state=7)

# specify the hyperparameters and their values
# 4 x 2 x 2 = 16 combinations in the grid
param_grid = {
    'n_estimators': [10, 100, 200, 500],
    'max_depth': [5, 15],
    'min_samples_split': [5, 10]
}

# we'll use 5-fold cross-validation
grid_search = GridSearchCV(rf3, param_grid, cv=5, 
                           return_train_score=True) 

start = time.time()
grid_search.fit(Xtrain3, ytrain3)
end = time.time() - start
print(f"Took {end} seconds")
# Out:
# Took 226.61497592926025 seconds

# %%
grid_search.best_score_
# Out:
# 0.9058933588171325

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=15, min_samples_split=5, n_estimators=500,
#                       random_state=7)

# %%
# put them into a separate variable for convenience
feature_importances = grid_search.best_estimator_.feature_importances_

# the order of the features in `feature_importances` is the same as in the Xtrain dataframe,
# so we can "zip" the two and print in the descending order:

for k, v in sorted(zip(feature_importances, Xtrain3.columns), reverse=True):
    print(f"{v}: {k}")
# Out:
# Tackling: 0.763937180382626
# age: 0.0512852279937012
# reactions: 0.04914510829338913
# ball_control: 0.024373784868559577
# marking: 0.024342862393584505
# positioning: 0.011597691662807434
# interceptions: 0.010668228758874703
# Passing: 0.0095820139533095
# sprint_speed: 0.008210798625300747
# heading_accuracy: 0.007909679541592812
# composure: 0.006912011699116894
# aggression: 0.0060463953344225985
# strength: 0.005789256160158113
# acceleration: 0.005350882004137282
# stamina: 0.005078891447749348
# jumping: 0.00400582257973815
# balance: 0.0031239457990705974
# agility: 0.0026402185018613413

# %%
rf3 = RandomForestRegressor(n_estimators = 500, max_features = 'sqrt', max_depth = 15,
                           random_state = 18)
rf3.fit(Xtrain3, ytrain3)
# Out:
# RandomForestRegressor(max_depth=15, max_features='sqrt', n_estimators=500,
#                       random_state=18)

# %%
score = rf3.score(Xtrain3, ytrain3)
print("R-squared:", score)
# Out:
# R-squared: 0.9867116639086209

# %%
ypred = rf3.predict(Xtest3)

mse = mean_squared_error(ytest3, ypred)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('MAE:', metrics.mean_absolute_error(ytest3, ypred))
# Out:
# MSE:  1.5646915970990531
# RMSE:  1.2508763316567522
# MAE: 0.4474133049566119

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
regressor = LinearRegression()  
regressor.fit(Xtrain1, ytrain1) #training the algorithm
# Out:
# LinearRegression()

# %%
score = regressor.score(Xtrain1, ytrain1)
print("R-squared:", score)
# Out:
# R-squared: 0.4579605608354389

# %%
y_pred1 = regressor.predict(Xtest1)
mse = mean_squared_error(ytest1, y_pred1)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('MAE:', metrics.mean_absolute_error(ytest1, y_pred1))
# Out:
# MSE:  17.01412439785169
# RMSE:  4.1248181048201005
# MAE: 2.2977447122743087

# %%
# put them into a separate variable for convenience
feature_importances = regressor.coef_

# the order of the features in `feature_importances` is the same as in the Xtrain dataframe,
# so we can "zip" the two and print in the descending order:

for k, v in sorted(zip(feature_importances, Xtrain1.columns), reverse=True):
    print(f"{v}: {k}")
# Out:
# reactions: 1.4165131894422216
# short_passing: 1.1259817585886582
# ball_control: 0.7680904339056623
# composure: 0.484511403810758
# dribbling: 0.4355892906224085
# finishing: 0.36232989560390544
# marking: 0.3215772150184928
# positioning: 0.25599754716598205
# stamina: 0.18845052916116597
# acceleration: 0.16905192482414919
# vision: 0.16047837346953067
# balance: 0.14323376017018746
# heading_accuracy: 0.10320911516761458
# sprint_speed: 0.09362849837545523
# strength: 0.07982128138623733
# long_passing: 0.07644027604316334
# crossing: 0.05454615961370805
# skill_moves(1-5): -0.006089003751575953
# aggression: -0.034340038880506345
# interceptions: -0.12383367022839588
# Tackling: -0.1238903571538219
# agility: -0.2195287686273559
# long_shots: -0.4128988837567359
# age: -1.3392052320640857

# %%
regressor = LinearRegression()  
regressor.fit(Xtrain2, ytrain2) #training the algorithm
# Out:
# LinearRegression()

# %%
score = regressor.score(Xtrain2, ytrain2)
print("R-squared:", score)
# Out:
# R-squared: 0.4597773901255726

# %%
y_pred2 = regressor.predict(Xtest2)
mse = mean_squared_error(ytest2, y_pred2)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('MAE:', metrics.mean_absolute_error(ytest2, y_pred2))
# Out:
# MSE:  22.14496557080716
# RMSE:  4.7058437682106655
# MAE: 3.017996958368367

# %%
# put them into a separate variable for convenience
feature_importances = regressor.coef_

# the order of the features in `feature_importances` is the same as in the Xtrain dataframe,
# so we can "zip" the two and print in the descending order:

for k, v in sorted(zip(feature_importances, Xtrain2.columns), reverse=True):
    print(f"{v}: {k}")
# Out:
# reactions: 1.5738616437920032
# finishing: 1.4956711434518708
# ball_control: 1.2902920444469974
# vision: 0.961095045485116
# composure: 0.7381382175684519
# positioning: 0.6797488009450638
# balance: 0.5748622430015785
# acceleration: 0.4753825095632678
# volleys: 0.46060292916774687
# stamina: 0.3177528003381054
# long_shots: 0.2989475258628053
# strength: 0.20590446990258812
# long_passing: 0.12180705653051731
# sprint_speed: 0.09789229358050949
# aggression: -0.00913958697898718
# crossing: -0.014145427963299465
# dribbling: -0.046072424297178484
# jumping: -0.08796729334346469
# heading_accuracy: -0.10991112588847994
# short_passing: -0.15083805332920008
# skill_moves(1-5): -0.26658637575406374
# shot_power: -0.44352137446230316
# agility: -0.4771320125216288
# age: -2.0675947349190613

# %%
regressor = LinearRegression()  
regressor.fit(Xtrain3, ytrain3) #training the algorithm
# Out:
# LinearRegression()

# %%
score = regressor.score(Xtrain3, ytrain3)
print("R-squared:", score)
# Out:
# R-squared: 0.4956399250178377

# %%
y_pred3 = regressor.predict(Xtest3)
mse = mean_squared_error(ytest3, y_pred3)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('MAE:', metrics.mean_absolute_error(ytest3, y_pred3))
# Out:
# MSE:  9.217385809131125
# RMSE:  3.0360147906640913
# MAE: 1.6900338176516476

# %%
# put them into a separate variable for convenience
feature_importances = regressor.coef_

# the order of the features in `feature_importances` is the same as in the Xtrain dataframe,
# so we can "zip" the two and print in the descending order:

for k, v in sorted(zip(feature_importances, Xtrain3.columns), reverse=True):
    print(f"{v}: {k}")
# Out:
# reactions: 1.1484925272083948
# Tackling: 0.9686632660600359
# marking: 0.5412071337297316
# composure: 0.48193565608789934
# sprint_speed: 0.3868592919037046
# heading_accuracy: 0.33065571572219277
# jumping: 0.1646378164798726
# Passing: 0.13005495220704819
# interceptions: 0.11350123840655506
# positioning: 0.08862221660471804
# aggression: 0.07077630962395899
# acceleration: 0.037035348895932074
# ball_control: -0.001345358767442802
# strength: -0.04460763517316094
# stamina: -0.08247309138998898
# balance: -0.11091660988449378
# agility: -0.1734119570827358
# age: -1.2038337396214784

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(ytest3,y_pred3);
plt.xlabel('Actual');
plt.ylabel('Predicted');

# %%
import seaborn as sns

# %%
sns.regplot(x=ytest3,y=y_pred3,ci=None,color ='red');

# %%
pred_df=pd.DataFrame({'Actual Value':ytest3,'Predicted Value':y_pred,'Difference':ytest3-y_pred})
pred_df
# Out:
#       Actual Value  Predicted Value  Difference
# 0            0.525         2.495173   -1.970173
# 1            7.500         6.559779    0.940221
# 2            0.975         2.031254   -1.056254
# 3            0.675         2.103469   -1.428469
# 4            0.070        -3.540483    3.610483
# ...            ...              ...         ...
# 1178         6.000         6.758726   -0.758726
# 1179         0.210        -2.167175    2.377175
# 1180         4.800         5.502641   -0.702641
# 1181         0.110        -3.745542    3.855542
# 1182         0.200        -0.453308    0.653308
#
# [1183 rows x 3 columns]

# %%
sns.regplot(x=ytest2,y=y_pred2,ci=None,color ='red');

# %%
sns.regplot(x=ytest1,y=y_pred1,ci=None,color ='red');
